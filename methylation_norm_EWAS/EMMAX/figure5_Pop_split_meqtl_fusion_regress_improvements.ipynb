# %%
##baseline EWAS
library("ggplot2")
library("dplyr")
library("cowplot")
plot_list <- list()
load("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/meqtl_cpgs.RData")
load("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/heritable_cpgs.RData")
library(ggplot2)
sig_sites <- function(df){
    n <- nrow(df)
    df_subset <- subset(df, P.value < .05/n)}
print("here")
# for(pop in c( "KHS", "Baka", "Himba")){
# if(pop == "Baka") {best_covs <- read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/Baka_sex_methPC23_Neutro_genoPC12345_no_meqtl_regress.ps", header=FALSE)}
# if(pop == "Himba") {best_covs <-  read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/Himba_sex_cpPCs_Neutro_genoPCs_no_meqtl_regress.ps", header=FALSE)}
# if(pop == "KHS") {best_covs <-  read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/KHS_sex_batch_PC13_meth_Neutro_genoPCs_no_meqtl_regress.ps", header=FALSE)}
# colnames(best_covs)<-c("CPG.Labels","V2","P.value")
                    

# if(pop == "Baka") {best_covs_meqtl <- read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/Baka_sex_methPC23_Neutro_genoPC12345_meqtl_regressed.ps", header=FALSE)}
# if(pop == "Himba") {best_covs_meqtl <-  read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/Himba_sex_cpPCs_Neutro_genoPCs_meqtl_regressed.ps", header=FALSE)}
# if(pop == "KHS") {best_covs_meqtl <-  read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/KHS_sex_batch_PC13_meth_Neutro_genoPCs_meqtl_regressed.ps", header=FALSE)}
# colnames(best_covs_meqtl)<-c("CPG.Labels","V2","P.value")


# if(pop == "Baka") {best_covs_fusion <- read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/Baka_sex_methPC23_Neutro_genoPC12345_fusion_regressed.ps", header=FALSE)}
# if(pop == "Himba") {best_covs_fusion <-  read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/Himba_sex_cpPCs_Neutro_genoPCs_fusion_regressed.ps", header=FALSE)}
# if(pop == "KHS") {best_covs_fusion <-  read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/KHS_sex_batch_PC13_meth_Neutro_genoPCs_fusion_regressed.ps", header=FALSE)}
# colnames(best_covs_fusion)<-c("CPG.Labels","V2","P.value")

# no_regress_sig <- best_covs
# print(paste0("sig sites in meta no regress: ", nrow(no_regress_sig)))
# pop_meqtls <- get(paste0(pop, "_meqtl_cpgs"))
# no_regress_sig_meqtl_cpgs <- no_regress_sig %>% filter(CPG.Labels %in% pop_meqtls)
# meqtl_regress_sig_cpgs <- best_covs_meqtl %>% filter(CPG.Labels %in% no_regress_sig_meqtl_cpgs$CPG.Labels)
# # Calculate -log(p-value) for both datasets
# no_regress_sig_meqtl_cpgs$p_value_old <- -log10(no_regress_sig_meqtl_cpgs$P.value)
# meqtl_regress_sig_cpgs$p_value_meqtls <- -log10(meqtl_regress_sig_cpgs$P.value)

# # Merge the datasets
# p_val <- merge(no_regress_sig_meqtl_cpgs, meqtl_regress_sig_cpgs, by = "CPG.Labels", suffixes = c("_old", "_meqtls"))
# # Calculate improvement in p-values
# p_val <- p_val %>% mutate(diff = p_value_meqtls - p_value_old)

# # Calculate percentage of time p-value improved with meqtl regression
# improved_ratio <- nrow(p_val[p_val$p_value_old < p_val$p_value_meqtls - 1, ])/nrow(p_val)
# p_val$improved <- FALSE
# p_val[p_val$p_value_old < p_val$p_value_meqtls - 1, "improved"] <- TRUE

# if(pop == "KHS") {pop <- "Khomani"}
#     print(paste0("percent of time p-value improved with meqtl regression for sig_sites: ", improved_ratio))

# # Add a column to indicate if the point corresponds to most improved
# p_val$IsTarget <- ifelse(p_val$diff == max(p_val$diff), TRUE, FALSE)
    
# print(p_val[p_val$IsTarget,])

# p_val[p_val$diff == max(p_val$diff),]

# # Plot

# p <- ggplot(p_val, aes(x = p_value_old, y = p_value_meqtls)) +
#  geom_point(data = subset(p_val, IsTarget == FALSE), aes(size = 3), color = "black", alpha=0.3) +
#   geom_point(data = subset(p_val, IsTarget == TRUE), aes(size = 3), color = "red") +
#       geom_ribbon(aes(ymin = p_value_old - 1, ymax = p_value_old + 1), alpha = 0.4, fill = "blue") +

#   labs(
#     x = "-log(P-value) Unadjusted",
#     y = "-log(P-value) Top MeQTL Regressed"
#   ) +
#   geom_abline(slope = 1, intercept = 0, linetype = "dashed", color = "red") +
#   theme_minimal() +
#   theme(
#     axis.text = element_text(size = 30),        # Increase axis text size
#     axis.title = element_text(size = 30, face = "bold"),  # Increase axis title size
#     plot.title = element_text(size = 30, face = "bold") ,
#        legend.position = "none" # Increase plot title size
#   ) + labs( title= paste0(pop))
# plot_list[[pop]] <- p
    
# }
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
# [1] "here"

# %%
# options(repr.plot.width = 30, repr.plot.height = 10)

# cow_AC <- plot_grid(plot_list[["Khomani"]], plot_list[["Baka"]], plot_list[["Himba"]], ncol = 3, labels = c("A", "B", "C"),
#                     label_size = 40)

# %%
for(pop in c( "KHS", "Baka", "Himba")){
    print(pop)
if(pop == "Baka") {best_covs <- read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/Baka_sex_methPC23_Neutro_genoPC12345_no_meqtl_regress.ps", header=FALSE)}
if(pop == "Himba") {best_covs <-  read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/Himba_sex_cpPCs_Neutro_genoPCs_no_meqtl_regress.ps", header=FALSE)}
if(pop == "KHS") {best_covs <-  read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/KHS_sex_batch_PC13_meth_Neutro_genoPCs_no_meqtl_regress.ps", header=FALSE)}
colnames(best_covs)<-c("CPG.Labels","V2","P.value")
                    

if(pop == "Baka") {best_covs_meqtl <- read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/Baka_sex_methPC23_Neutro_genoPC12345_meqtl_regressed.ps", header=FALSE)}
if(pop == "Himba") {best_covs_meqtl <-  read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/Himba_sex_cpPCs_Neutro_genoPCs_meqtl_regressed.ps", header=FALSE)}
if(pop == "KHS") {best_covs_meqtl <-  read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/KHS_sex_batch_PC13_meth_Neutro_genoPCs_meqtl_regressed.ps", header=FALSE)}
colnames(best_covs_meqtl)<-c("CPG.Labels","V2","P.value")

###if testing fusion###  also change to heritable cpgs
#if(pop == "Baka") {best_covs_meqtl <- read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/Baka_sex_methPC23_Neutro_genoPC12345_fusion_regressed.ps", header=FALSE)}
#if(pop == "Himba") {best_covs_meqtl <-  read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/Himba_sex_cpPCs_Neutro_genoPCs_fusion_regressed.ps", header=FALSE)}
#if(pop == "KHS") {best_covs_meqtl <-  read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/KHS_sex_batch_PC13_meth_Neutro_genoPCs_fusion_regressed.ps", header=FALSE)}
colnames(best_covs_meqtl)<-c("CPG.Labels","V2","P.value")

no_regress_sig <- best_covs 
    ##can switch to just sig sites
    #no_regress_sig <- sig_sites(best_covs)
print(paste0("sig sites in meta no regress: ", nrow(no_regress_sig)))
pop_meqtls <- get(paste0(pop, "_meqtl_cpgs"))
#pop_meqtls <- get(paste0(pop, "_heritable_cpgs"))
no_regress_sig_meqtl_cpgs <- no_regress_sig %>% filter(CPG.Labels %in% pop_meqtls)
print(nrow(no_regress_sig_meqtl_cpgs))
meqtl_regress_sig_cpgs <- best_covs_meqtl %>% filter(CPG.Labels %in% no_regress_sig_meqtl_cpgs$CPG.Labels)
# Calculate -log(p-value) for both datasets
no_regress_sig_meqtl_cpgs$p_value_old <- -log10(no_regress_sig_meqtl_cpgs$P.value)
meqtl_regress_sig_cpgs$p_value_meqtls <- -log10(meqtl_regress_sig_cpgs$P.value)

# Merge the datasets
p_val <- merge(no_regress_sig_meqtl_cpgs, meqtl_regress_sig_cpgs, by = "CPG.Labels", suffixes = c("_old", "_meqtls"))
# Calculate improvement in p-values
p_val <- p_val %>% mutate(diff = p_value_meqtls - p_value_old)

# Calculate percentage of time p-value improved with meqtl regression
improved_ratio <- nrow(p_val[p_val$p_value_old < p_val$p_value_meqtls - 1, ])/nrow(p_val)
p_val$improved <- FALSE
p_val[p_val$p_value_old < p_val$p_value_meqtls - 1, "improved"] <- TRUE

    print(paste0("percent of time p-value improved with meqtl regression for sig_sites: ", improved_ratio))

# Add a column to indicate if the point corresponds to most improved
p_val$IsTarget <- FALSE
if(pop == "KHS") { p_val[p_val$CPG.Labels == "cg23448486", "IsTarget"] <- TRUE }
if(pop == "Baka") { p_val[p_val$CPG.Labels == "cg15060012", "IsTarget"] <- TRUE }
if(pop == "Himba"){ p_val[p_val$CPG.Labels == "cg01265905", "IsTarget"] <- TRUE }

print(p_val[p_val$IsTarget,])

p_val[p_val$diff == max(p_val$diff),]

# Plot

    

p <- ggplot(p_val, aes(x = p_value_old, y = p_value_meqtls)) +
 geom_point(data = subset(p_val, IsTarget == FALSE), aes(size = 3), color = "black", alpha=0.3) +
  geom_point(data = subset(p_val, IsTarget == TRUE), aes(size = 3), color = "red") +
      #geom_ribbon(aes(ymin = p_value_old - 1, ymax = p_value_old + 1), alpha = 0.2, fill = "blue") +

  labs(
    x = "-log(P-value) Unadjusted",
    y = "-log(P-value) Top MeQTL Regressed"
  ) +
  geom_abline(slope = 1, intercept = 0, linetype = "dashed", color = "red") +
 theme_bw() + 
     theme_bw(base_size = 50) + 
  theme(legend.position = "none",
         axis.text = element_text(size = 30),
        axis.title = element_text(size = 30, margin = margin(r = 10)),
        plot.title = element_text(size = 50 ), plot.margin = margin(t = 20, r = 20, b = 20, l = 20)) 

total_sig_sites_improved_ratio <- c()    
    
    i <- 1
        while(i < 11){
            fake_meqtl_regress <- read.delim(paste0("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/fake_perms/", i, "beta_fake_meqtl_regress_", pop, ".ps"), header = FALSE)
            colnames(fake_meqtl_regress)<-c("CPG.Labels","V2","P.value")
            fake_meqtl_regress_meqtl_cpgs <- fake_meqtl_regress %>% filter(CPG.Labels %in%  no_regress_sig_meqtl_cpgs$CPG.Labels)            
            fake_meqtl_regress_meqtl_cpgs$p_value_meqtls <- -log10(fake_meqtl_regress_meqtl_cpgs$P.value)
            no_regress_sig_meqtl_cpgs$p_value_old <- -log10(no_regress_sig_meqtl_cpgs$P.value)          
            p_val <- merge(no_regress_sig_meqtl_cpgs, fake_meqtl_regress_meqtl_cpgs, by = "CPG.Labels", suffixes = c("_old", "_meqtls"))
            p_val <- p_val %>% mutate(diff = p_value_meqtls - p_value_old) 
            improved_ratio <- mean(p_val$p_value_old < p_val$p_value_meqtls - 1)
            total_sig_sites_improved_ratio <- c(total_sig_sites_improved_ratio, improved_ratio)
            p <- p + geom_point(data=p_val, aes(size = 3), color = "orange", alpha=0.1)
                      
            i <- i + 1
        
        }


print(mean(total_sig_sites_improved_ratio))

        if(pop == "KHS") {pop <- "\u2021Khomani San"}
p <- p + labs( title= paste0(pop))

plot_list[[pop]] <- p
    
}
# Out:
# [1] "KHS"
# [1] "sig sites in meta no regress: 418629"
# [1] 46441
# [1] "percent of time p-value improved with meqtl regression for sig_sites: 0.0255377791175901"
#       CPG.Labels   V2_old P.value_old p_value_old V2_meqtls P.value_meqtls
# 39737 cg23448486 376.5305 0.002330399     2.63257   577.173   3.159064e-07
#       p_value_meqtls     diff improved IsTarget
# 39737       6.500442 3.867872     TRUE     TRUE
# [1] 0.0007924033
# [1] "Baka"
# [1] "sig sites in meta no regress: 400893"
# [1] 32167
# [1] "percent of time p-value improved with meqtl regression for sig_sites: 0.0680200205179221"
#       CPG.Labels   V2_old P.value_old p_value_old V2_meqtls P.value_meqtls
# 18760 cg15060012 4.704913   0.9009848  0.04528255  326.3939   6.454605e-06
#       p_value_meqtls     diff improved IsTarget
# 18760        5.19013 5.144848     TRUE     TRUE
# [1] 0.0005782323
# [1] "Himba"
# [1] "sig sites in meta no regress: 713771"
# [1] 83527
# ...

# %%
##P-value improvement for meta_ewas
sig_sites <- function(df){
    n <- nrow(df)
    df_subset <- subset(df, P.value.fix < .05/n)}
load("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/metagen_all3_no_meqtl_regress.RData")
meta_no_regress <- meta_gen
load("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/metagen_all3_meqtl_regressed.RData")
#load("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/metagen_all3_fusion_regressed.RData")

meta_meqtl_regress <- meta_gen
####for sig sites#########
#meta_no_regress <- sig_sites(meta_no_regress)

###############################
paste0("sig sites in meta no regress: ", nrow(meta_no_regress))

meta_no_regress_sig_meqtl_cpgs <- meta_no_regress %>% filter(CPG.Labels %in% pop_spec_meqtl_cpgs)
print(nrow(meta_no_regress_sig_meqtl_cpgs))
#if fusion
#meta_no_regress_sig_meqtl_cpgs <- meta_no_regress %>% filter(CPG.Labels %in% pop_spec_herirable_cpgs)

meta_meqtl_regress_sig_cpgs <- meta_meqtl_regress %>% filter(CPG.Labels %in% meta_no_regress_sig_meqtl_cpgs$CPG.Labels)
paste0("sig sites that have an meqtl: ", nrow(meta_no_regress_sig_meqtl_cpgs))

# Calculate -log(p-value) for both datasets
meta_no_regress_sig_meqtl_cpgs$p_value_old <- -log10(meta_no_regress_sig_meqtl_cpgs$P.value.fix)
meta_meqtl_regress_sig_cpgs$p_value_meqtls <- -log10(meta_meqtl_regress_sig_cpgs$P.value.fix)

# Merge the datasets
p_val <- merge(meta_no_regress_sig_meqtl_cpgs, meta_meqtl_regress_sig_cpgs, by = "CPG.Labels", suffixes = c("_old", "_meqtls"))

# Calculate improvement in p-values
p_val <- p_val %>% mutate(diff = p_value_meqtls - p_value_old)
nrow(p_val)
# Calculate percentage of time p-value improved with meqtl regression
improved_ratio <-nrow(p_val[p_val$p_value_old < p_val$p_value_meqtls - 1, ])/nrow(p_val)
paste0("percent of time p-value improved with meqtl regression: ", improved_ratio)
p_val[p_val$diff == max(p_val$diff),]

p <- ggplot(p_val, aes(x = p_value_old, y = p_value_meqtls)) +
 geom_point(data = p_val, aes(size = 3), color = "black", alpha=0.3, pch=16) +
  #eom_point(data = subset(p_val, IsTarget == TRUE), aes(size = 3), color = "red") +
      #geom_ribbon(aes(ymin = p_value_old - 1, ymax = p_value_old + 1), alpha = 0.2, fill = "blue") +

  labs(
    x = "-log(P-value) Unadjusted",
    y = "-log(P-value) Top MeQTL Regressed"
  ) +
  geom_abline(slope = 1, intercept = 0, linetype = "dashed", color = "red") +
theme_bw() + 
     theme_bw(base_size = 50) + 
  theme(legend.position = "none",
        axis.text = element_text(size = 30),
        axis.title = element_text(size = 30, margin = margin(r = 10)),
         
        plot.title = element_text(size = 50 ), plot.margin = margin(t = 20, r = 20, b = 20, l = 20)) + labs(title= "Meta-analysis")


total_sig_sites_improved_ratio <- c()

load("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/metagen_all3_no_meqtl_regress.RData")
meta_no_regress <- meta_gen

i <- 1
while(i < 11){
    load(paste0("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/fake_perms/metagen_all3_fake_meqtl_regressed",i,".RData"))
    fake_meqtl_regress <- meta_gen
    #meta_no_regress <- sig_sites(meta_no_regress)
    meta_no_regress_sig_meqtl_cpgs <- meta_no_regress %>% filter(CPG.Labels %in% pop_spec_meqtl_cpgs)
    fake_meqtl_regress_meqtl_cpgs <- fake_meqtl_regress %>% filter(CPG.Labels %in%  meta_no_regress_sig_meqtl_cpgs$CPG.Labels)    
    fake_meqtl_regress_meqtl_cpgs$p_value_meqtls <- -log10(fake_meqtl_regress_meqtl_cpgs$P.value.fix)
    meta_no_regress_sig_meqtl_cpgs$p_value_old <- -log10(meta_no_regress_sig_meqtl_cpgs$P.value.fix)
     
    p_val <- merge(meta_no_regress_sig_meqtl_cpgs, fake_meqtl_regress_meqtl_cpgs, by = "CPG.Labels", suffixes = c("_old", "_meqtls"))
    p_val <- p_val %>% mutate(diff = p_value_meqtls - p_value_old) 
    improved_ratio <- mean(p_val$p_value_old < p_val$p_value_meqtls - 1)
    total_sig_sites_improved_ratio <- c(total_sig_sites_improved_ratio, improved_ratio)
    i <- i + 1
     p <- p + geom_point(data=p_val, aes(size = 3), color = "orange", alpha=0.1)


}
p
mean(total_sig_sites_improved_ratio)
# Out:
# [1] "sig sites in meta no regress: 355103"
# [1] 85080
# [1] "sig sites that have an meqtl: 85080"
# [1] 85080
# [1] "percent of time p-value improved with meqtl regression: 0.0236013164080865"
#       CPG.Labels P.value.random_old P.value.fix_old het.P.value_old p_value_old
# 83614 cg27193080 0.02933241         0.003872848     0.120397        2.411969
#       P.value.random_meqtls P.value.fix_meqtls het.P.value_meqtls
# 83614 8.106292e-10          8.106292e-10       0.7964312
#       p_value_meqtls diff
# 83614 9.091178       6.679208
# [1] 0.0003361542
# plot without title

# %%
options(repr.plot.width = 23, repr.plot.height = 7 )

plot_grid(plot_list[["\u2021Khomani San"]], plot_list[["Himba"]], plot_list[["Baka"]], p, ncol = 4) 
top <- plot_grid(plot_list[["\u2021Khomani San"]], plot_list[["Himba"]], plot_list[["Baka"]], p, ncol = 4, labels = c("A", "B", "C", "D"),
                    label_size = 35)
# Out:
# plot without title

# %%
options(repr.plot.width = 30, repr.plot.height = 10)
#svg("Figure5_pop_split_meqtl_regress.png", width=30, height=20)
load("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/most_improved_sites_pop_split_meqtl.RData")
combined_plot
#plot_grid(top, combined_plot, nrow=2)
#dev.off()
# Out:
# plot without title

# %%
options(repr.plot.width = 30, repr.plot.height = 20)
    

load("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/most_improved_sites_pop_split_meqtl.RData")
plot_grid(top, combined_plot, nrow=2)
# Out:
# plot without title

# %%
for(pop in c( "KHS", "Baka", "Himba")){
    print(pop)
if(pop == "Baka") {best_covs <- read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/Baka_sex_methPC23_Neutro_genoPC12345_no_meqtl_regress.ps", header=FALSE)}
if(pop == "Himba") {best_covs <-  read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/Himba_sex_cpPCs_Neutro_genoPCs_no_meqtl_regress.ps", header=FALSE)}
if(pop == "KHS") {best_covs <-  read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/KHS_sex_batch_PC13_meth_Neutro_genoPCs_no_meqtl_regress.ps", header=FALSE)}
colnames(best_covs)<-c("CPG.Labels","V2","P.value")
                    


###if testing fusion###  also change to heritable cpgs
if(pop == "Baka") {best_covs_meqtl <- read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/Baka_sex_methPC23_Neutro_genoPC12345_fusion_regressed.ps", header=FALSE)}
if(pop == "Himba") {best_covs_meqtl <-  read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/Himba_sex_cpPCs_Neutro_genoPCs_fusion_regressed.ps", header=FALSE)}
if(pop == "KHS") {best_covs_meqtl <-  read.delim("/share/hennlab/users/glmeeks/age_methylation/EMMAX_meqtl/KHS_sex_batch_PC13_meth_Neutro_genoPCs_fusion_regressed.ps", header=FALSE)}
colnames(best_covs_meqtl)<-c("CPG.Labels","V2","P.value")

no_regress_sig <- best_covs 
    ##can switch to just sig sites
    #no_regress_sig <- sig_sites(best_covs)
print(paste0("sig sites in meta no regress: ", nrow(no_regress_sig)))
pop_meqtls <- get(paste0(pop, "_meqtl_cpgs"))
#pop_meqtls <- get(paste0(pop, "_heritable_cpgs"))
no_regress_sig_meqtl_cpgs <- no_regress_sig %>% filter(CPG.Labels %in% pop_meqtls)
print(nrow(no_regress_sig_meqtl_cpgs))
meqtl_regress_sig_cpgs <- best_covs_meqtl %>% filter(CPG.Labels %in% no_regress_sig_meqtl_cpgs$CPG.Labels)
# Calculate -log(p-value) for both datasets
no_regress_sig_meqtl_cpgs$p_value_old <- -log10(no_regress_sig_meqtl_cpgs$P.value)
meqtl_regress_sig_cpgs$p_value_meqtls <- -log10(meqtl_regress_sig_cpgs$P.value)

# Merge the datasets
p_val <- merge(no_regress_sig_meqtl_cpgs, meqtl_regress_sig_cpgs, by = "CPG.Labels", suffixes = c("_old", "_meqtls"))
# Calculate improvement in p-values
p_val <- p_val %>% mutate(diff = p_value_meqtls - p_value_old)

# Calculate percentage of time p-value improved with meqtl regression
improved_ratio <- nrow(p_val[p_val$p_value_old < p_val$p_value_meqtls - 1, ])/nrow(p_val)
p_val$improved <- FALSE
p_val[p_val$p_value_old < p_val$p_value_meqtls - 1, "improved"] <- TRUE

    print(paste0("percent of time p-value improved with meqtl regression for sig_sites: ", improved_ratio))

# Add a column to indicate if the point corresponds to most improved
p_val$IsTarget <- FALSE
if(pop == "KHS") { p_val[p_val$CPG.Labels == "cg23448486", "IsTarget"] <- TRUE }
if(pop == "Baka") { p_val[p_val$CPG.Labels == "cg15060012", "IsTarget"] <- TRUE }
if(pop == "Himba"){ p_val[p_val$CPG.Labels == "cg01265905", "IsTarget"] <- TRUE }

print(p_val[p_val$IsTarget,])

print(p_val[p_val$diff == min(p_val$diff),])

    
}
# Out:
# [1] "KHS"
# [1] "sig sites in meta no regress: 418629"
# [1] 46441
# [1] "percent of time p-value improved with meqtl regression for sig_sites: 0.012833487650998"
#       CPG.Labels   V2_old P.value_old p_value_old V2_meqtls P.value_meqtls
# 39737 cg23448486 376.5305 0.002330399     2.63257   577.173   3.159063e-07
#       p_value_meqtls     diff improved IsTarget
# 39737       6.500442 3.867872     TRUE     TRUE
#      CPG.Labels    V2_old  P.value_old p_value_old V2_meqtls P.value_meqtls
# 8887 cg04581938 -655.5678 9.703306e-08     7.01308  3164.328      0.3308196
#      p_value_meqtls      diff improved IsTarget
# 8887      0.4804088 -6.532671    FALSE    FALSE
# [1] "Baka"
# [1] "sig sites in meta no regress: 400893"
# [1] 32167
# [1] "percent of time p-value improved with meqtl regression for sig_sites: 0.0170982684117263"
#       CPG.Labels   V2_old P.value_old p_value_old V2_meqtls P.value_meqtls
# 18760 cg15060012 4.704913   0.9009848  0.04528255  4.704914      0.9009847
# ...
